# %% [markdown]
# ## Autoencoder convolucional

# %% [markdown]
# ## Instalando bibliotecas

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Importação da base cifar10
from keras.datasets import cifar10
from keras.models import Model, Sequential
from keras.layers import Input, Dense

# %% [markdown]
# ## Carregamento base de dados

# %%
(previsores_treinamento, _), (previsores_teste, _) = cifar10.load_data()

# %%
previsores_treinamento.shape, previsores_teste.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3))

# %% [markdown]
# ## Preprocessamento da base - normalizacao

# %%
previsores_treinamento = previsores_treinamento.astype('float32') / 255
previsores_teste = previsores_teste.astype('float32') / 255

# %%
previsores_treinamento.shape, previsores_teste.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3))

# %% [markdown]
# ## Ajuste nos dados

# %%
# Como essa base de dados apresenta imagens coloridas temos 3 canais e não somente
# um canal como na base MNIST. As dimensão dessas imagens é 32 x 32, portanto
# teremos um total de 3072 características (32 x 32 x 3 canais)
previsores_treinamento = previsores_treinamento.reshape((len(previsores_treinamento), np.prod(previsores_treinamento.shape[1:])))
previsores_teste = previsores_teste.reshape((len(previsores_teste), np.prod(previsores_teste.shape[1:])))

# %% [markdown]
# ## Criação do Autoencoder

# %%
# Criação do autoencoder
autoencoder = Sequential()

# ENCODE
# Estrutura do encoder: 3072 - 1536 - 768 - 1536 - 3072
# Você pode testar com outras arquiteturas também, mas uma dica é dividir as
# dimensões pela metade. Por exemplo, para chegar no valor de 1536 dividimos
# 3072 / 2 e para chegar no valor de 768 dividimos 1532 / 2

# Trabalharemos com a dimensão mínima de 768, ou seja, de 3072 pixels reduziremos para 768
# Como são imagens com mais pixels, se diminuirmos muito a dimensão final o autoencoder
# pode apresentar resultados ruins
# O número de entradas é 3072 que equivale ao número total de pixels da imagem
autoencoder.add(Dense(units = 1536, activation = 'relu', input_dim = 3072))
autoencoder.add(Dense(units = 768, activation='relu'))

# DECODE
# Faz o processo inverso, ou seja, 768 - 1536 - 3072
autoencoder.add(Dense(units = 1536, activation='relu'))
autoencoder.add(Dense(units = 3072, activation='sigmoid'))
autoencoder.summary()
# Out:
# /home/lucas/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1536)           │     4,720,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 768)            │     1,180,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1536)           │     1,181,184 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 3072)           │     4,721,664 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,803,392 (45.03 MB)
#  Trainable params: 11,803,392 (45.03 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compilação e aprendizagem, mantendo os parâmetros padrões
# Os resultados não serão tão bons caso use um número pequeno de épocas
autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics = ['accuracy'])
autoencoder.fit(previsores_treinamento, previsores_treinamento,
                epochs=100, batch_size=256, validation_data=(previsores_teste, previsores_teste))
# Out:
# Epoch 1/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 37s 184ms/step - accuracy: 0.0020 - loss: 0.6511 - val_accuracy: 0.0042 - val_loss: 0.6026
# Epoch 2/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 42s 189ms/step - accuracy: 0.0040 - loss: 0.5962 - val_accuracy: 0.0051 - val_loss: 0.5868
# Epoch 3/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 37s 190ms/step - accuracy: 0.0062 - loss: 0.5850 - val_accuracy: 0.0070 - val_loss: 0.5817
# Epoch 4/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 38s 176ms/step - accuracy: 0.0076 - loss: 0.5812 - val_accuracy: 0.0081 - val_loss: 0.5789
# Epoch 5/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 46s 203ms/step - accuracy: 0.0079 - loss: 0.5781 - val_accuracy: 0.0097 - val_loss: 0.5777
# Epoch 6/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 59s 294ms/step - accuracy: 0.0100 - loss: 0.5766 - val_accuracy: 0.0138 - val_loss: 0.5756
# Epoch 7/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 59s 300ms/step - accuracy: 0.0119 - loss: 0.5744 - val_accuracy: 0.0125 - val_loss: 0.5741
# Epoch 8/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 56s 286ms/step - accuracy: 0.0120 - loss: 0.5733 - val_accuracy: 0.0124 - val_loss: 0.5725
# Epoch 9/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 57s 291ms/step - accuracy: 0.0134 - loss: 0.5711 - val_accuracy: 0.0133 - val_loss: 0.5718
# Epoch 10/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 59s 303ms/step - accuracy: 0.0144 - loss: 0.5712 - val_accuracy: 0.0128 - val_loss: 0.5717
# Epoch 11/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 59s 299ms/step - accuracy: 0.0149 - loss: 0.5706 - val_accuracy: 0.0131 - val_loss: 0.5714
# Epoch 12/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 59s 299ms/step - accuracy: 0.0160 - loss: 0.5691 - val_accuracy: 0.0159 - val_loss: 0.5705
# Epoch 13/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 59s 301ms/step - accuracy: 0.0161 - loss: 0.5684 - val_accuracy: 0.0153 - val_loss: 0.5689
# Epoch 14/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 59s 185ms/step - accuracy: 0.0174 - loss: 0.5686 - val_accuracy: 0.0152 - val_loss: 0.5697
# Epoch 15/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 36s 181ms/step - accuracy: 0.0164 - loss: 0.5674 - val_accuracy: 0.0168 - val_loss: 0.5686
# Epoch 16/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 36s 182ms/step - accuracy: 0.0183 - loss: 0.5675 - val_accuracy: 0.0178 - val_loss: 0.5681
# Epoch 17/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 41s 182ms/step - accuracy: 0.0187 - loss: 0.5668 - val_accuracy: 0.0170 - val_loss: 0.5678
# Epoch 18/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 51s 233ms/step - accuracy: 0.0188 - loss: 0.5665 - val_accuracy: 0.0171 - val_loss: 0.5716
# Epoch 19/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 53s 272ms/step - accuracy: 0.0205 - loss: 0.5670 - val_accuracy: 0.0153 - val_loss: 0.5678
# Epoch 20/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 76s 239ms/step - accuracy: 0.0180 - loss: 0.5662 - val_accuracy: 0.0158 - val_loss: 0.5676
# Epoch 21/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 103s 349ms/step - accuracy: 0.0198 - loss: 0.5653 - val_accuracy: 0.0174 - val_loss: 0.5676
# Epoch 22/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 69s 353ms/step - accuracy: 0.0188 - loss: 0.5663 - val_accuracy: 0.0221 - val_loss: 0.5662
# Epoch 23/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 77s 328ms/step - accuracy: 0.0220 - loss: 0.5652 - val_accuracy: 0.0202 - val_loss: 0.5680
# Epoch 24/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 63s 231ms/step - accuracy: 0.0211 - loss: 0.5652 - val_accuracy: 0.0217 - val_loss: 0.5657
# Epoch 25/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 95s 298ms/step - accuracy: 0.0203 - loss: 0.5648 - val_accuracy: 0.0202 - val_loss: 0.5661
# Epoch 26/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 88s 327ms/step - accuracy: 0.0220 - loss: 0.5650 - val_accuracy: 0.0199 - val_loss: 0.5655
# Epoch 27/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 81s 322ms/step - accuracy: 0.0208 - loss: 0.5646 - val_accuracy: 0.0226 - val_loss: 0.5649
# Epoch 28/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 82s 322ms/step - accuracy: 0.0226 - loss: 0.5652 - val_accuracy: 0.0193 - val_loss: 0.5660
# Epoch 29/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 50s 255ms/step - accuracy: 0.0224 - loss: 0.5640 - val_accuracy: 0.0254 - val_loss: 0.5651
# Epoch 30/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 66s 335ms/step - accuracy: 0.0239 - loss: 0.5642 - val_accuracy: 0.0201 - val_loss: 0.5655
# Epoch 31/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 80s 324ms/step - accuracy: 0.0221 - loss: 0.5640 - val_accuracy: 0.0226 - val_loss: 0.5643
# Epoch 32/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 85s 340ms/step - accuracy: 0.0251 - loss: 0.5635 - val_accuracy: 0.0205 - val_loss: 0.5663
# Epoch 33/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 66s 256ms/step - accuracy: 0.0240 - loss: 0.5639 - val_accuracy: 0.0210 - val_loss: 0.5662
# Epoch 34/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 95s 321ms/step - accuracy: 0.0251 - loss: 0.5640 - val_accuracy: 0.0256 - val_loss: 0.5649
# Epoch 35/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 54s 275ms/step - accuracy: 0.0242 - loss: 0.5640 - val_accuracy: 0.0233 - val_loss: 0.5643
# Epoch 36/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 81s 270ms/step - accuracy: 0.0251 - loss: 0.5627 - val_accuracy: 0.0218 - val_loss: 0.5645
# Epoch 37/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 83s 276ms/step - accuracy: 0.0246 - loss: 0.5633 - val_accuracy: 0.0219 - val_loss: 0.5697
# Epoch 38/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 38s 195ms/step - accuracy: 0.0242 - loss: 0.5633 - val_accuracy: 0.0266 - val_loss: 0.5637
# Epoch 39/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 49s 251ms/step - accuracy: 0.0250 - loss: 0.5632 - val_accuracy: 0.0245 - val_loss: 0.5640
# Epoch 40/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 83s 256ms/step - accuracy: 0.0254 - loss: 0.5636 - val_accuracy: 0.0212 - val_loss: 0.5645
# Epoch 41/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 76s 223ms/step - accuracy: 0.0256 - loss: 0.5630 - val_accuracy: 0.0224 - val_loss: 0.5650
# Epoch 42/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 84s 233ms/step - accuracy: 0.0270 - loss: 0.5638 - val_accuracy: 0.0269 - val_loss: 0.5641
# Epoch 43/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 102s 334ms/step - accuracy: 0.0255 - loss: 0.5629 - val_accuracy: 0.0263 - val_loss: 0.5643
# Epoch 44/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 79s 318ms/step - accuracy: 0.0259 - loss: 0.5626 - val_accuracy: 0.0201 - val_loss: 0.5638
# Epoch 45/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 79s 301ms/step - accuracy: 0.0259 - loss: 0.5625 - val_accuracy: 0.0305 - val_loss: 0.5634
# Epoch 46/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 87s 326ms/step - accuracy: 0.0278 - loss: 0.5625 - val_accuracy: 0.0249 - val_loss: 0.5633
# Epoch 47/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 96s 399ms/step - accuracy: 0.0272 - loss: 0.5627 - val_accuracy: 0.0211 - val_loss: 0.5655
# Epoch 48/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 82s 396ms/step - accuracy: 0.0264 - loss: 0.5623 - val_accuracy: 0.0239 - val_loss: 0.5634
# Epoch 49/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 62s 316ms/step - accuracy: 0.0265 - loss: 0.5624 - val_accuracy: 0.0275 - val_loss: 0.5638
# Epoch 50/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 62s 315ms/step - accuracy: 0.0260 - loss: 0.5621 - val_accuracy: 0.0234 - val_loss: 0.5635
# Epoch 51/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 63s 323ms/step - accuracy: 0.0257 - loss: 0.5622 - val_accuracy: 0.0285 - val_loss: 0.5632
# Epoch 52/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 83s 328ms/step - accuracy: 0.0286 - loss: 0.5617 - val_accuracy: 0.0259 - val_loss: 0.5629
# Epoch 53/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 87s 352ms/step - accuracy: 0.0278 - loss: 0.5619 - val_accuracy: 0.0274 - val_loss: 0.5630
# Epoch 54/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 65s 334ms/step - accuracy: 0.0269 - loss: 0.5620 - val_accuracy: 0.0248 - val_loss: 0.5637
# Epoch 55/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 38s 194ms/step - accuracy: 0.0270 - loss: 0.5620 - val_accuracy: 0.0240 - val_loss: 0.5629
# Epoch 56/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 42s 201ms/step - accuracy: 0.0284 - loss: 0.5614 - val_accuracy: 0.0259 - val_loss: 0.5628
# Epoch 57/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 41s 199ms/step - accuracy: 0.0273 - loss: 0.5623 - val_accuracy: 0.0272 - val_loss: 0.5626
# Epoch 58/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 39s 188ms/step - accuracy: 0.0262 - loss: 0.5618 - val_accuracy: 0.0243 - val_loss: 0.5634
# Epoch 59/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 43s 201ms/step - accuracy: 0.0266 - loss: 0.5608 - val_accuracy: 0.0267 - val_loss: 0.5637
# Epoch 60/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 36s 181ms/step - accuracy: 0.0280 - loss: 0.5619 - val_accuracy: 0.0269 - val_loss: 0.5632
# Epoch 61/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 49s 252ms/step - accuracy: 0.0288 - loss: 0.5613 - val_accuracy: 0.0278 - val_loss: 0.5626
# Epoch 62/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 68s 178ms/step - accuracy: 0.0277 - loss: 0.5610 - val_accuracy: 0.0294 - val_loss: 0.5623
# Epoch 63/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 39s 196ms/step - accuracy: 0.0291 - loss: 0.5610 - val_accuracy: 0.0271 - val_loss: 0.5625
# Epoch 64/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 47s 237ms/step - accuracy: 0.0296 - loss: 0.5614 - val_accuracy: 0.0295 - val_loss: 0.5624
# Epoch 65/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 73s 192ms/step - accuracy: 0.0269 - loss: 0.5621 - val_accuracy: 0.0247 - val_loss: 0.5625
# Epoch 66/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 39s 180ms/step - accuracy: 0.0299 - loss: 0.5612 - val_accuracy: 0.0253 - val_loss: 0.5636
# Epoch 67/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 43s 192ms/step - accuracy: 0.0284 - loss: 0.5615 - val_accuracy: 0.0303 - val_loss: 0.5631
# Epoch 68/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 40s 203ms/step - accuracy: 0.0287 - loss: 0.5611 - val_accuracy: 0.0261 - val_loss: 0.5631
# Epoch 69/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 38s 188ms/step - accuracy: 0.0289 - loss: 0.5614 - val_accuracy: 0.0263 - val_loss: 0.5627
# Epoch 70/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 38s 195ms/step - accuracy: 0.0288 - loss: 0.5618 - val_accuracy: 0.0259 - val_loss: 0.5626
# Epoch 71/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 44s 224ms/step - accuracy: 0.0301 - loss: 0.5613 - val_accuracy: 0.0247 - val_loss: 0.5633
# Epoch 72/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 55s 279ms/step - accuracy: 0.0289 - loss: 0.5611 - val_accuracy: 0.0257 - val_loss: 0.5635
# Epoch 73/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 80s 269ms/step - accuracy: 0.0296 - loss: 0.5614 - val_accuracy: 0.0235 - val_loss: 0.5638
# Epoch 74/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 51s 258ms/step - accuracy: 0.0277 - loss: 0.5613 - val_accuracy: 0.0291 - val_loss: 0.5623
# Epoch 75/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 79s 245ms/step - accuracy: 0.0295 - loss: 0.5611 - val_accuracy: 0.0302 - val_loss: 0.5632
# Epoch 76/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 47s 238ms/step - accuracy: 0.0292 - loss: 0.5609 - val_accuracy: 0.0263 - val_loss: 0.5624
# Epoch 77/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 51s 258ms/step - accuracy: 0.0296 - loss: 0.5610 - val_accuracy: 0.0251 - val_loss: 0.5624
# Epoch 78/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 86s 280ms/step - accuracy: 0.0299 - loss: 0.5608 - val_accuracy: 0.0264 - val_loss: 0.5623
# Epoch 79/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 83s 285ms/step - accuracy: 0.0291 - loss: 0.5607 - val_accuracy: 0.0256 - val_loss: 0.5626
# Epoch 80/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 76s 253ms/step - accuracy: 0.0289 - loss: 0.5606 - val_accuracy: 0.0268 - val_loss: 0.5623
# Epoch 81/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 79s 236ms/step - accuracy: 0.0299 - loss: 0.5602 - val_accuracy: 0.0280 - val_loss: 0.5624
# Epoch 82/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 44s 223ms/step - accuracy: 0.0292 - loss: 0.5609 - val_accuracy: 0.0258 - val_loss: 0.5632
# Epoch 83/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 44s 222ms/step - accuracy: 0.0279 - loss: 0.5613 - val_accuracy: 0.0274 - val_loss: 0.5624
# Epoch 84/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 50s 256ms/step - accuracy: 0.0289 - loss: 0.5612 - val_accuracy: 0.0293 - val_loss: 0.5619
# Epoch 85/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 83s 260ms/step - accuracy: 0.0315 - loss: 0.5612 - val_accuracy: 0.0271 - val_loss: 0.5621
# Epoch 86/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 47s 239ms/step - accuracy: 0.0306 - loss: 0.5609 - val_accuracy: 0.0272 - val_loss: 0.5625
# Epoch 87/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 84s 248ms/step - accuracy: 0.0301 - loss: 0.5610 - val_accuracy: 0.0258 - val_loss: 0.5624
# Epoch 88/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 82s 250ms/step - accuracy: 0.0315 - loss: 0.5605 - val_accuracy: 0.0269 - val_loss: 0.5628
# Epoch 89/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 47s 240ms/step - accuracy: 0.0297 - loss: 0.5607 - val_accuracy: 0.0280 - val_loss: 0.5624
# Epoch 90/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 76s 210ms/step - accuracy: 0.0294 - loss: 0.5608 - val_accuracy: 0.0303 - val_loss: 0.5625
# Epoch 91/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 41s 210ms/step - accuracy: 0.0297 - loss: 0.5610 - val_accuracy: 0.0252 - val_loss: 0.5634
# Epoch 92/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 85s 229ms/step - accuracy: 0.0280 - loss: 0.5606 - val_accuracy: 0.0257 - val_loss: 0.5623
# Epoch 93/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 45s 230ms/step - accuracy: 0.0300 - loss: 0.5604 - val_accuracy: 0.0305 - val_loss: 0.5621
# Epoch 94/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 39s 200ms/step - accuracy: 0.0277 - loss: 0.5602 - val_accuracy: 0.0297 - val_loss: 0.5620
# Epoch 95/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 40s 195ms/step - accuracy: 0.0301 - loss: 0.5610 - val_accuracy: 0.0307 - val_loss: 0.5624
# Epoch 96/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 45s 214ms/step - accuracy: 0.0298 - loss: 0.5613 - val_accuracy: 0.0265 - val_loss: 0.5621
# Epoch 97/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 76s 184ms/step - accuracy: 0.0304 - loss: 0.5603 - val_accuracy: 0.0278 - val_loss: 0.5618
# Epoch 98/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 41s 208ms/step - accuracy: 0.0281 - loss: 0.5610 - val_accuracy: 0.0269 - val_loss: 0.5626
# Epoch 99/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 42s 214ms/step - accuracy: 0.0302 - loss: 0.5604 - val_accuracy: 0.0287 - val_loss: 0.5617
# Epoch 100/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 38s 193ms/step - accuracy: 0.0311 - loss: 0.5605 - val_accuracy: 0.0286 - val_loss: 0.5624

# %% [markdown]
# ## Visualizar resultados

# %%
# Cria um novo modelo para capturar somente a aprendizagem da rede, que é o codificador
dimensao_original = Input(shape=(3072,))
camada_encoder1 = autoencoder.layers[0]
camada_encoder2 = autoencoder.layers[1]
encoder = Model(dimensao_original, camada_encoder2(camada_encoder1(dimensao_original)))
encoder.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1536)           │     4,720,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 768)            │     1,180,416 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,900,544 (22.51 MB)
#  Trainable params: 5,900,544 (22.51 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Cria as variáveis com as imagens codificadas e decodificadas
imagens_codificadas = encoder.predict(previsores_teste)
imagens_decodificadas = autoencoder.predict(previsores_teste)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step

# %%
# Visualiza 10 imagens escolhidas aleatoriamente
numero_imagens = 10
imagens_teste = np.random.randint(previsores_teste.shape[0], size=numero_imagens)
plt.figure(figsize=(18, 18))
for i, indice_imagem in enumerate(imagens_teste):
    # Imagem original, nas dimensões 32x32 com 3 canais
    eixo = plt.subplot(10, 10, i + 1)
    plt.imshow(previsores_teste[indice_imagem].reshape(32, 32, 3))
    plt.xticks(())
    plt.yticks(())
    
    # Imagem codificada, nas dimensões 16x16 com 3 canais
    # Se multiplicar os três valores teremos o valor mínimo que é 768 pixels
    eixo = plt.subplot(10, 10, numero_imagens + i + 1)
    plt.imshow(imagens_codificadas[indice_imagem].reshape(16, 16, 3))
    plt.xticks(())
    plt.yticks(())

    # Imagem decodificada, nas dimensões 32x32 com 3 canais
    eixo = plt.subplot(10, 10, 2 * numero_imagens + i + 1)
    plt.imshow(imagens_decodificadas[indice_imagem].reshape(32, 32, 3))
    plt.xticks(())
    plt.yticks(())
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
