# %% [markdown]
# # **APRENDIZAGEM NÃO SUPERVISIONADA: ASSOCIAÇÃO**

# %% [markdown]
# Este projeto tem por objetivo desenvolver um algoritmo de Machine Learning para associar produtos de mercado.

# %% [markdown]
# Os dados foram extraídos do site do Kaggle:
#
# https://www.kaggle.com/heeraldedhia/groceries-dataset

# %%
from pyECLAT import Example2
dados = Example2().get()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
dados.head()
# Out:
#                0          1           2                 3             4  \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                   5     6
# 0  whole weat flour  yams
# 1               NaN   NaN
# 2               NaN   NaN
# 3               NaN   NaN
# 4               NaN   NaN

# %%
dados.shape
# Out:
# (3001, 7)

# %% [markdown]
# ## **ANÁLISE, TRATAMENTO E PRÉ-PROCESSAMENTO DOS DADOS**

# %% [markdown]
# **Valores Missing (NAN)**

# %%
# RELAÇÃO DA QUANTIDADE
dados.isnull().sum()
# Out:
# 0       0
# 1     686
# 2    1227
# 3    1627
# 4    1953
# 5    2226
# 6    2420
# dtype: int64

# %% [markdown]
# **Análise dos tipos de atributos.**

# %%
# object: strings
# int64: inteiros
# float64: reais
# complex: complexos
dados.dtypes
# Out:
# 0    object
# 1    object
# 2    object
# 3    object
# 4    object
# 5    object
# 6    object
# dtype: object

# %%
dados2 = df.groupby(['Member_number', 'itemDescription'])['itemDescription'].count().unstack().fillna(0).applymap(
    lambda x: 1 if x > 0 else 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 dados2 = df.groupby(['Member_number', 'itemDescription'])['itemDescription'].count().unstack().fillna(0).applymap(
#       2     lambda x: 1 if x > 0 else 0)
#
# NameError: name 'df' is not defined

# %%
df2
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 1000                                 0         0                 0
# 1001                                 0         0                 0
# 1002                                 0         0                 0
# 1003                                 0         0                 0
# 1004                                 0         0                 0
# ...                                ...       ...               ...
# 4996                                 0         0                 0
# 4997                                 0         0                 0
# 4998                                 0         0                 0
# 4999                                 0         0                 0
# 5000                                 0         0                 0
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# 1000                            0               0     0              0
# 1001                            0               0     0              0
# 1002                            0               0     0              0
# 1003                            0               0     0              0
# 1004                            0               0     0              0
# ...                           ...             ...   ...            ...
# 4996                            0               0     0              0
# 4997                            0               0     0              0
# 4998                            0               0     0              0
# 4999                            0               0     0              0
# 5000                            0               0     0              0
#
# itemDescription  bathroom cleaner  beef  berries  ...  turkey  vinegar  \
# Member_number                                     ...
# 1000                            0     0        0  ...       0        0
# 1001                            0     1        0  ...       0        0
# 1002                            0     0        0  ...       0        0
# 1003                            0     0        0  ...       0        0
# 1004                            0     0        0  ...       0        0
# ...                           ...   ...      ...  ...     ...      ...
# 4996                            0     0        0  ...       0        0
# 4997                            0     0        0  ...       0        0
# 4998                            0     0        0  ...       0        0
# 4999                            0     0        1  ...       0        0
# 5000                            0     0        0  ...       0        0
#
# itemDescription  waffles  whipped/sour cream  whisky  white bread  white wine  \
# Member_number
# 1000                   0                   0       0            0           0
# 1001                   0                   1       0            1           0
# 1002                   0                   0       0            0           0
# 1003                   0                   0       0            0           0
# 1004                   0                   0       0            0           0
# ...                  ...                 ...     ...          ...         ...
# 4996                   0                   0       0            0           0
# 4997                   0                   0       0            0           1
# 4998                   0                   0       0            0           0
# 4999                   0                   1       0            0           0
# 5000                   0                   0       0            0           0
#
# itemDescription  whole milk  yogurt  zwieback
# Member_number
# 1000                      1       1         0
# 1001                      1       0         0
# 1002                      1       0         0
# 1003                      0       0         0
# 1004                      1       0         0
# ...                     ...     ...       ...
# 4996                      0       0         0
# 4997                      1       0         0
# 4998                      0       0         0
# 4999                      0       1         0
# 5000                      0       0         0
#
# [3898 rows x 167 columns]

# %%
df2.iloc[0:12, 0:12]
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 1000                                 0         0                 0
# 1001                                 0         0                 0
# 1002                                 0         0                 0
# 1003                                 0         0                 0
# 1004                                 0         0                 0
# 1005                                 0         0                 0
# 1006                                 0         0                 0
# 1008                                 0         0                 0
# 1009                                 0         0                 0
# 1010                                 0         1                 0
# 1011                                 0         0                 0
# 1012                                 0         0                 0
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# 1000                            0               0     0              0
# 1001                            0               0     0              0
# 1002                            0               0     0              0
# 1003                            0               0     0              0
# 1004                            0               0     0              0
# 1005                            0               0     0              0
# 1006                            0               0     0              0
# 1008                            0               0     0              0
# 1009                            0               0     0              0
# 1010                            0               0     0              0
# 1011                            0               0     0              0
# 1012                            0               0     0              0
#
# itemDescription  bathroom cleaner  beef  berries  beverages  bottled beer
# Member_number
# 1000                            0     0        0          0             0
# 1001                            0     1        0          0             0
# 1002                            0     0        0          0             0
# 1003                            0     0        0          0             0
# 1004                            0     0        0          0             0
# 1005                            0     0        0          0             0
# 1006                            0     0        0          0             1
# 1008                            0     0        0          0             0
# 1009                            0     0        0          0             0
# 1010                            0     0        0          0             0
# 1011                            0     0        0          0             0
# 1012                            0     0        0          0             0

# %%
df2.shape
# Out:
# (3898, 167)

# %% [markdown]
# ## **APRIORI**

# %%
# !pip install mlxtend
# Out:
# /home/lucas/anaconda3/lib/python3.12/pty.py:95: DeprecationWarning: This process (pid=7498) is multi-threaded, use of forkpty() may lead to deadlocks in the child.
#   pid, fd = os.forkpty()
# Requirement already satisfied: mlxtend in /home/lucas/anaconda3/lib/python3.12/site-packages (0.23.1)
# Requirement already satisfied: scipy>=1.2.1 in /home/lucas/anaconda3/lib/python3.12/site-packages (from mlxtend) (1.13.1)
# Requirement already satisfied: numpy>=1.16.2 in /home/lucas/anaconda3/lib/python3.12/site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in /home/lucas/anaconda3/lib/python3.12/site-packages (from mlxtend) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.0.2 in /home/lucas/anaconda3/lib/python3.12/site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /home/lucas/anaconda3/lib/python3.12/site-packages (from mlxtend) (3.8.4)
# Requirement already satisfied: joblib>=0.13.2 in /home/lucas/anaconda3/lib/python3.12/site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/lucas/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/lucas/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/lucas/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/lucas/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/lucas/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (23.2)
# Requirement already satisfied: pillow>=8 in /home/lucas/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/lucas/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/lucas/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/lucas/anaconda3/lib/python3.12/site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/lucas/anaconda3/lib/python3.12/site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/lucas/anaconda3/lib/python3.12/site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in /home/lucas/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# Gerando a associação
associacao = apriori(df2, min_support=0.05, use_colnames=True)
# Out:
# /home/lucas/anaconda3/lib/python3.12/site-packages/mlxtend/frequent_patterns/fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
# Colocando em ordem dos mais frequentes
associacao.sort_values("support", ascending=False).head(10)
# Out:
#       support                        itemsets
# 55   0.458184                    (whole milk)
# 37   0.376603              (other vegetables)
# 41   0.349666                    (rolls/buns)
# 47   0.313494                          (soda)
# 56   0.282966                        (yogurt)
# 51   0.233710                (tropical fruit)
# 42   0.230631               (root vegetables)
# 5    0.213699                 (bottled water)
# 44   0.206003                       (sausage)
# 116  0.191380  (other vegetables, whole milk)

# %%
# Criando as regras de associação
regras = association_rules(associacao, metric="lift")

# %%
# Colocando em ordem de suporte, confiança ou grau de associação (Lift)
resultado = regras.sort_values("support", ascending=False)

# %%
resultado.head(20)
# Out:
#             antecedents         consequents  antecedent support  \
# 118  (other vegetables)        (whole milk)            0.376603
# 119        (whole milk)  (other vegetables)            0.458184
# 152        (whole milk)        (rolls/buns)            0.458184
# 153        (rolls/buns)        (whole milk)            0.349666
# 182        (whole milk)              (soda)            0.458184
# 183              (soda)        (whole milk)            0.313494
# 193            (yogurt)        (whole milk)            0.282966
# 192        (whole milk)            (yogurt)            0.458184
# 105        (rolls/buns)  (other vegetables)            0.349666
# 104  (other vegetables)        (rolls/buns)            0.376603
# 113              (soda)  (other vegetables)            0.313494
# 112  (other vegetables)              (soda)            0.376603
# 121            (yogurt)  (other vegetables)            0.282966
# 120  (other vegetables)            (yogurt)            0.376603
# 146              (soda)        (rolls/buns)            0.313494
# 147        (rolls/buns)              (soda)            0.349666
# 187    (tropical fruit)        (whole milk)            0.233710
# 186        (whole milk)    (tropical fruit)            0.458184
# 163        (whole milk)   (root vegetables)            0.458184
# 162   (root vegetables)        (whole milk)            0.230631
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 118            0.458184  0.191380    0.508174  1.109106  0.018827    1.101643
# 119            0.376603  0.191380    0.417693  1.109106  0.018827    1.070564
# 152            0.349666  0.178553    0.389698  1.114484  0.018342    1.065592
# 153            0.458184  0.178553    0.510638  1.114484  0.018342    1.107190
# 182            0.313494  0.151103    0.329787  1.051973  0.007465    1.024310
# 183            0.458184  0.151103    0.481997  1.051973  0.007465    1.045971
# 193            0.458184  0.150590    0.532185  1.161510  0.020940    1.158185
# 192            0.282966  0.150590    0.328667  1.161510  0.020940    1.068076
# 105            0.376603  0.146742    0.419663  1.114335  0.015056    1.074197
# 104            0.349666  0.146742    0.389646  1.114335  0.015056    1.065502
# 113            0.376603  0.124166    0.396072  1.051695  0.006103    1.032237
# 112            0.313494  0.124166    0.329700  1.051695  0.006103    1.024178
# 121            0.376603  0.120318    0.425204  1.129050  0.013752    1.084553
# 120            0.282966  0.120318    0.319482  1.129050  0.013752    1.053660
# 146            0.349666  0.119805    0.382160  1.092928  0.010187    1.052593
# 147            0.313494  0.119805    0.342627  1.092928  0.010187    1.044316
# 187            0.458184  0.116470    0.498353  1.087672  0.009388    1.080076
# 186            0.233710  0.116470    0.254199  1.087672  0.009388    1.027473
# 163            0.230631  0.113135    0.246920  1.070630  0.007464    1.021630
# 162            0.458184  0.113135    0.490545  1.070630  0.007464    1.063522
#
#      zhangs_metric
# 118       0.157802
# 119       0.181562
# 152       0.189591
# 153       0.157955
# 182       0.091184
# 183       0.071966
# 193       0.193926
# 192       0.256640
# 105       0.157772
# 104       0.164589
# 113       0.071601
# 112       0.078849
# 121       0.159406
# 120       0.183350
# 146       0.123855
# 147       0.130743
# 187       0.105189
# 186       0.148768
# 163       0.121758
# 162       0.085746
